# %% [markdown]
# <a href="https://colab.research.google.com/github/kararmirza19/kararmirza19/blob/main/AI_LAB_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_csv("/content/catalog.csv")
data.head(4)
# Out:
#    id     date   time continent_code   country_name country_code  \
# 0  34   3/2/07  Night            NaN  United States           US
# 1  42  3/22/07    NaN            NaN  United States           US
# 2  56   4/6/07    NaN            NaN  United States           US
# 3  59  4/14/07    NaN            NaN         Canada           CA
#
#   state/province  population         city/town  distance  ...  \
# 0       Virginia       16000       Cherry Hill   3.40765  ...
# 1           Ohio       17288  New Philadelphia   3.33522  ...
# 2   Pennsylvania       15930       Wilkinsburg   2.91977  ...
# 3         Quebec       42786       Châteauguay   2.98682  ...
#
#                                  geolocation  hazard_type      landslide_type  \
# 0  (38.600900000000003, -77.268199999999993)    Landslide           Landslide
# 1  (40.517499999999998, -81.430499999999995)    Landslide           Landslide
# 2             (40.4377, -79.915999999999997)    Landslide           Landslide
# ...

# %%
data.tail(10)
# Out:
#         id      date   time continent_code   country_name country_code  \
# 1683  7530   2/27/16  15:30            NaN  United States           US
# 1684  7531   2/14/16    NaN            NaN  United States           US
# 1685  7532   2/26/16  15:00            NaN  United States           US
# 1686  7533   2/27/16  12:15            NaN  United States           US
# 1687  7534  11/29/15    NaN            NaN  United States           US
# 1688  7535   12/7/15    NaN            NaN  United States           US
# 1689  7537   2/22/16   0:00            NaN  United States           US
# 1690  7539   2/23/16    NaN            NaN  United States           US
# 1691  7540   2/26/16  21:06            NaN  United States           US
# 1692  7541    3/2/16   8:00            NaN  United States           US
#
#       state/province  population   city/town  distance  ...  \
# 1683           Idaho         485  Idaho City  24.16064  ...
# 1684        Colorado       16887     Durango  22.57467  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1693 non-null   int64
#  1   date                  1690 non-null   object
#  2   time                  629 non-null    object
#  3   continent_code        164 non-null    object
#  4   country_name          1693 non-null   object
#  5   country_code          1693 non-null   object
#  6   state/province        1692 non-null   object
#  7   population            1693 non-null   int64
#  8   city/town             1689 non-null   object
#  9   distance              1692 non-null   float64
#  10  location_description  551 non-null    object
#  11  latitude              1692 non-null   float64
#  12  longitude             1692 non-null   float64
#  13  geolocation           1692 non-null   object
#  14  hazard_type           1693 non-null   object
# ...

# %%
data.describe()
# Out:
#                 id    population     distance     latitude    longitude  \
# count  1693.000000  1.693000e+03  1692.000000  1692.000000  1692.000000
# mean   4145.027761  9.345940e+04     7.822695    27.715661   -86.883660
# std    2236.741960  5.226016e+05     9.358256    14.206341    14.332811
# min      34.000000  0.000000e+00     0.000030   -10.125800  -117.309200
# 25%    2330.000000  2.080000e+03     1.936360    14.085650   -92.646625
# 50%    4087.000000  5.785000e+03     4.538635    35.613200   -83.653000
# 75%    6098.000000  1.886700e+04     9.873865    39.546400   -78.851325
# max    7541.000000  1.229419e+07    74.460970    45.425700   -45.601000
#
#          injuries   fatalities
# count  515.000000  1446.000000
# mean     0.526214     1.459198
# std      3.427514     9.184653
# min      0.000000     0.000000
# 25%      0.000000     0.000000
# 50%      0.000000     0.000000
# 75%      0.000000     0.000000
# max     45.000000   280.000000

# %%
data.count
# Out:
# id                      1693
# date                    1690
# time                     629
# continent_code           164
# country_name            1693
# country_code            1693
# state/province          1692
# population              1693
# city/town               1689
# distance                1692
# location_description     551
# latitude                1692
# longitude               1692
# geolocation             1692
# hazard_type             1693
# landslide_type          1692
# landslide_size          1692
# trigger                 1691
# storm_name               132
# injuries                 515
# fatalities              1446
# source_name              872
# source_link             1593
# dtype: int64

# %%
data.max()
# Out:
# <ipython-input-27-8637789457d2>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()
# id                   7541
# country_name    Venezuela
# country_code           VI
# population       12294193
# distance         74.46097
# latitude          45.4257
# longitude         -45.601
# hazard_type     Landslide
# injuries             45.0
# fatalities          280.0
# dtype: object

# %%
data.shape
# Out:
# (1693, 23)

# %%
data.sort_values(by=['distance'],ascending=True)
# Out:
#         id     date      time continent_code   country_name country_code  \
# 1220  5959  3/16/14       NaN             SA       Colombia           CO
# 776   3755   7/9/11       NaN            NaN  United States           US
# 33     230   9/5/07       NaN            NaN    El Salvador           SV
# 431   2353  8/28/10       NaN            NaN      Guatemala           GT
# 319   1815   5/3/10       NaN            NaN  United States           US
# ...    ...      ...       ...            ...            ...          ...
# 130    698   8/8/08       NaN            NaN  United States           US
# 1171  5590  10/8/13  11:30:00            NaN  United States           US
# 893   4470  8/12/12       NaN            NaN  United States           US
# 1465  6955  6/16/15       NaN            NaN  United States           US
# 596   3177   3/7/11   2:00:00            NaN  United States           US
#
#      state/province  population             city/town  distance  ...  \
# ...

# %%
data.query('country_name == "United States"')
# Out:
#         id     date   time continent_code   country_name country_code  \
# 0       34   3/2/07  Night            NaN  United States           US
# 1       42  3/22/07    NaN            NaN  United States           US
# 2       56   4/6/07    NaN            NaN  United States           US
# 4       61  4/15/07    NaN            NaN  United States           US
# 5       64  4/20/07    NaN            NaN  United States           US
# ...    ...      ...    ...            ...            ...          ...
# 1688  7535  12/7/15    NaN            NaN  United States           US
# 1689  7537  2/22/16   0:00            NaN  United States           US
# 1690  7539  2/23/16    NaN            NaN  United States           US
# 1691  7540  2/26/16  21:06            NaN  United States           US
# 1692  7541   3/2/16   8:00            NaN  United States           US
#
#       state/province  population         city/town  distance  ...  \
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
plt.plot(datalongitude,data,latitude)

# %%
data.size
# Out:
# 38939

# %%
data.columns
# Out:
# Index(['id', 'date', 'time', 'continent_code', 'country_name', 'country_code',
#        'state/province', 'population', 'city/town', 'distance',
#        'location_description', 'latitude', 'longitude', 'geolocation',
#        'hazard_type', 'landslide_type', 'landslide_size', 'trigger',
#        'storm_name', 'injuries', 'fatalities', 'source_name', 'source_link'],
#       dtype='object')
